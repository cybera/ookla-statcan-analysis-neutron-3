# %% [markdown]
# # Test Notebook
# Here's a basic notebook making sure some basic examples of libraries can be imported.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.linspace(-10,10, 500)
y1 = 1.2*np.sin(5*x) #sinusoid
y2 = 1.2*x * 0.01*x**2-0.0001*x**3 #linear trend with a bit of higher order polynomial
y3 = 1.2*np.random.randn(len(x)) # gaussian noise
y = y1+y2+y3

# %%
plt.rcParams['figure.figsize'] = [12,8]
plt.rcParams['font.size'] = 16

# %%
fix, ax = plt.subplots()
ax.plot(x, y)
ax.set(xlabel="X Axis Value Span (arbitrary units)", ylabel="Y Values, 2-model plus noise")
# Out:
# [Text(0.5, 0, 'X Axis Value Span (arbitrary units)'),
#  Text(0, 0.5, 'Y Values, 2-model plus noise')]

# %%
df = pd.DataFrame({"X":x, "Y":y})
df.describe()
# Out:
#                   X           Y
# count  5.000000e+02  500.000000
# mean  -4.547474e-16   -0.087190
# std    5.790855e+00    4.658414
# min   -1.000000e+01  -12.067796
# 25%   -5.000000e+00   -2.221018
# 50%    0.000000e+00   -0.121229
# 75%    5.000000e+00    2.180555
# max    1.000000e+01   11.675673
